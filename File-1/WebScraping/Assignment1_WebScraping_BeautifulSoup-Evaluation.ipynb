# %% [markdown]
# # ASSIGNMENT-2
# WEB SCRAPING

# %% [markdown]
# In all the following questions, you have to use BeautifulSoup to scrape different websites and collect data as per
# the requirement of the question.
# Every answer to the question should be in form of a python function which should take URL as the parameter.
# Use Jupyter Notebooks to program, upload it on your GitHub and send the link of the Jupyter notebook to
# your SME.
# 1) Write a python program to display IMDB’s Top rated 100 Indian movies’ data
# https://www.imdb.com/list/ls056092300/ (i.e. name, rating, year of release) and make data frame.
# 2) Write a python program to scrape product name, price and discounts from
# https://peachmode.com/search?q=bags
# 3) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
# b) Top 10 ODI Batsmen along with the records of their team and rating.
# c) Top 10 ODI bowlers along with the records of their team and rating.
# 4) Write a python program to scrape details of all the posts from https://www.patreon.com/coreyms .Scrape the
# heading, date, content and the likes for the video from the link for the youtube video from the post.
# 5) Write a python program to scrape house details from mentioned URL. It should include house title, location,
# area, EMI and price from https://www.nobroker.in/ .Enter three localities which are Indira Nagar, Jayanagar,
# Rajaji Nagar.
# 6) Write a python program to scrape first 10 product details which include product name , price , Image URL from
# https://www.bewakoof.com/bestseller?sort=popular .
#
# ADDED NEW QUESTIONS ON 1 MARCH
#
# Q1-Please visit https://www.cnbc.com/world/?region=world and scrap-
#
# a) headings
#
# b) date
#
# c) News link
#
# Q2-Please visit https://www.keaipublishing.com/en/journals/artificial-intelligence-in-agriculture/most-downloaded-articles/ and scrap-
#
# a) Paper title
#
# b) date
#
# c) Author

# %%
# !pip install bs4
# !pip install requests
# Out:
# Requirement already satisfied: bs4 in ./anaconda3/lib/python3.11/site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in ./anaconda3/lib/python3.11/site-packages (from bs4) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in ./anaconda3/lib/python3.11/site-packages (from beautifulsoup4->bs4) (2.4)
# Requirement already satisfied: requests in ./anaconda3/lib/python3.11/site-packages (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.11/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./anaconda3/lib/python3.11/site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.11/site-packages (from requests) (2023.5.7)

# %%
from bs4 import BeautifulSoup
import requests

import pandas as pd

# %% [markdown]
# Solution 1

# %%
def displaytopMovies(url):
    Page=requests.get(url)
    
    if Page.status_code==200:
        soup=BeautifulSoup(Page.content)
        name=[]
        rating=[]
        yearOfRelease=[]
        
        for i in soup.find_all("h3",class_="lister-item-header"):
            name.append(i.a.text.replace("\n",""))
           
        #print(name)
        for i in soup.find_all('div',class_="ipl-rating-star small"):
            rating.append(i.text.replace("\n","")) 
        #print(rating)
        for i in soup.find_all('span',class_="lister-item-year text-muted unbold"):
            yearOfRelease.append(i.text.strip('()'))
        #print(yearOfRelease)
        df=pd.DataFrame({'Movie name':name,'Rating':rating,'Year_Of_Release':yearOfRelease})
        print(df) 
        print(df.shape)
        #print(df.head(100))
    
        
    
    else:
        print("Page is not allowed to access:",Page.status_code)
    

Url="https://www.imdb.com/list/ls056092300/"
displaytopMovies(Url)
# Out:
#                            Movie name Rating Year_Of_Release
# 0                     Ship of Theseus      8            2012
# 1                              Iruvar    8.4            1997
# 2                     Kaagaz Ke Phool    7.8            1959
# 3   Lagaan: Once Upon a Time in India    8.1            2001
# 4                     Pather Panchali    8.2            1955
# ..                                ...    ...             ...
# 95                        Apur Sansar    8.4            1959
# 96                        Kanchivaram    8.2            2008
# 97                    Monsoon Wedding    7.3            2001
# 98                              Black    8.1            2005
# 99                            Deewaar      8            1975
#
# [100 rows x 3 columns]
# (100, 3)

# %% [markdown]
# Solution 2

# %%
from bs4 import BeautifulSoup
import requests

import pandas as pd

Page=requests.get("https://peachmode.com/search?q=bags")
soup=BeautifulSoup(Page.content)
Productname=[]
Price=[]

        
for i in soup.find_all('div',class_="product-title"):
    Productname.append(i.span.text.replace("$",""))
#print(Productname)            
for i in soup.find_all('span',class_="discounted_price st-money money done"):
    Price.append(i.text.strip()) 
#print(Price)   
       
       
#df=pd.DataFrame({'Product name':Productname,'PriceOfProduct':Price})
#print(df) 
#print(df.shape)
#print(df.head(100))

# %% [markdown]
# Solution 3 (a)

# %%
import pandas as pd
       
Page=requests.get("https://www.icc-cricket.com/rankings/team-rankings/mens/odi")
Page
soup=BeautifulSoup(Page.content)
teams=[]
matches=[]
points=[]
ratings=[]
for i in soup.find_all("h3",class_="si-team-name"):
    teams.append(i.span.text.replace('\n',' '))
print(teams)
for i in soup.find_all("div",class_="si-matches"):
    matches.append(i.span.text.replace('\n',' '))
print(matches)
for i in soup.find_all("div",class_="si-pts"):
    points.append(i.span.text.replace('\n',' '))
print(points)
for i in soup.find_all("div",class_="si-rating"):
    ratings.append(i.span.text.replace('\n',' '))
print(ratings)

# %% [markdown]
# Solution 3(b)

# %%
       
Page=requests.get("https://www.icc-cricket.com/rankings/batting/mens/odi")
Page
soup=BeautifulSoup(Page.content)
teams=[]
batsman=[]
ratings=[]
for i in soup.find_all("span",class_="si-sname"):
    teams.append(i.text.replace('\n',' '))
print(teams)
for i in soup.find_all("span",class_="si-lname"):
    batsman.append(i.text.replace('\n',' '))
print(batsman)
for i in soup.find_all("div",class_="si-rating"):
    ratings.append(i.span.text.replace('\n',' '))
print(ratings)

# %% [markdown]
# Solution 3(c)

# %%
       
Page=requests.get("https://www.icc-cricket.com/rankings/bowling/mens/odi")
Page
soup=BeautifulSoup(Page.content)


teams=[]
bowlers=[]
ratings=[]
for i in soup.find_all("span",class_="si-sname"):
    teams.append(i.text.replace('\n',' '))
print(teams)
for i in soup.find_all("a",class_="si-player-name-wrap"):
    bowlers.append(i.span.text.replace('\n',' '))
print(bowlers)
for i in soup.find_all("div",class_="si-rating"):
    ratings.append(i.span.text.replace('\n',' '))
print(ratings)

# %% [markdown]
# Solution 4

# %%
Page=requests.get("https://www.patreon.com/coreyms")
Page
soup=BeautifulSoup(Page.content)
heading=[]
date=[]
content=[]
likes=[]
for i in soup.find_all("span",class_="sc-1hmaiaw-0"):
    heading.append(i.text)
      
for i in soup.find_all('a',class_="bMyBFw"):
    date.append(i.text.replace("\n","")) 
        
for i in soup.find_all('div',class_="bCBphS"):
    content.append(i.text.replace("\n",""))
        
for i in soup.find_all('div',class_="sc-bdvvtL fyUgee"):
    likes.append(i.span.text) 
        

        
df=pd.DataFrame({'heading':heading,'date':date,'content':content,'likes':likes})
print(df) 
print(df.shape)

# %% [markdown]
# Solution 5

# %%
       
Page=requests.get("https://www.nobroker.in/property/sale/bangalore/multiple?searchParam=...&radius=2.0&city=bangalore&locality=Jayanagar,Indiranagar,Rajajinagar")
Page
soup=BeautifulSoup(Page.content)
house_title=[]
location_area=[]
EMI=[]
price=[] 
for i in soup.find_all("h2",class_="heading-6 flex items-center font-semi-bold m-0"):
    house_title.append(i.text.replace("\n",""))
#print(house_title)
#print(len(house_title))
for i in soup.find_all('div',class_="mt-0.5p overflow-hidden overflow-ellipsis whitespace-nowrap max-w-70 text-gray-light leading-4 po:mb-0.1p po:max-w-95"):
    location_area.append(i.text.replace("\xa0","")) 
#print(location_area) 
#print(len(location_area))        
for i in soup.find_all('div',id="roomType"):
    EMI.append(i.text.replace("\n","")) 
#print(EMI)
#print(len(EMI))
for i in soup.find_all('div',id="minDeposit"):
    price.append(i.text.replace("\n",""))
#print(price)
#print(len(price))        
df=pd.DataFrame({'house title':house_title,'location/area':location_area,'EMI':EMI,'price':price})
print(df.head(10)) 
#print(df.shape)
# Out:
#                                          house title  \
# 0  3 BHK Apartment In Brigade Gateway For Sale  I...
# 1  3 BHK House For Sale  In  Gopalapura, Rajajina...
# 2  3 BHK Apartment In Birla Tisya For Sale  In Ra...
# 3  4 BHK Apartment In Birla Tisya For Sale  In Ra...
# 4  2 BHK Flat In Pallava Terrace Apartments For S...
# 5              4+ BHK House For Sale  In Rajajinagar
# 6  3 BHK Flat In Santa Clara Apartment For Sale  ...
# 7  2 BHK Flat In Jayanagar Residency For Sale  In...
# 8  4 BHK Apartment In Phoenix Kessaku For Sale  I...
# 9  4+ BHK Apartment In Phoenix Kessaku For Sale  ...
#
#                                        location/area               EMI  \
# 0  Brigade Gateway Dr Rajkumar Road, Rajaji Nagar...   ₹4.3 Lacs/Month
# 1  Independent House, Gopalapura near  Sri Shanka...  ₹1.92 Lacs/Month
# 2  Birla Tisya  Near Sarvodaya College Of Hospita...  ₹1.38 Lacs/Month
# 3  Birla Tisya  Near Sarvodaya College Of Hospita...  ₹2.12 Lacs/Month
# 4  Pallava Terrace Apartments, North Main Road, o...     ₹57,314/Month
# 5  Independent House, SPECTRUM DIAGNOSTICS AND HE...  ₹3.55 Lacs/Month
# 6      3Rd Cross Rd18th main, 9th Block, Marenahalli     ₹65,911/Month
# 7  jayanager residency. near D mart, Jayanager 3r...     ₹80,240/Month
# 8  Phoenix Kessaku Opp. Vivekananda College,Dr Ra...  ₹4.67 Lacs/Month
# 9  Phoenix Kessaku Opp. Vivekananda College,Dr Ra...  ₹5.44 Lacs/Month
#
#                             price
# 0   ₹7.5 Crores₹23,810 per sq.ft.
# 1  ₹3.35 Crores₹18,611 per sq.ft.
# 2   ₹2.4 Crores₹14,484 per sq.ft.
# 3   ₹3.7 Crores₹14,776 per sq.ft.
# 4       ₹1 Crore₹9,524 per sq.ft.
# 5   ₹6.2 Crores₹18,235 per sq.ft.
# 6   ₹1.15 Crores₹8,244 per sq.ft.
# 7   ₹1.4 Crores₹11,997 per sq.ft.
# 8  ₹8.14 Crores₹25,866 per sq.ft.
# 9   ₹9.5 Crores₹26,049 per sq.ft.

# %% [markdown]
# Solution 6

# %%
       
Page=requests.get("https://www.bewakoof.com/bestseller?sort=popular")
Page
soup=BeautifulSoup(Page.content)
product_name=[]
price=[]
Image_URL=[]

for i in soup.find_all("h2",class_="clr-shade4"):
    product_name.append(i.text.replace("\n",""))
      
for i in soup.find_all('div',class_="discountedPriceText"):
    price.append(i.text.replace("\n","")) 
        
for i in soup.find_all('img',class_="wishlist-icon-animate"):
    Image_URL.append(i['src'])
    
df=pd.DataFrame({'product_name':product_name,'price':price,'Image_URL':Image_URL})
print(df) 
print(df.shape)
# Out:
#                                         product_name price  \
# 0  Women's Blue Round in Bugs Graphic Printed Ove...  ₹542
# 1            Women's Orange All Over Printed Pyjamas  ₹499
# 2                              Women's Black Pyjamas  ₹599
# 3            Men's Black Batman Outline Logo T-shirt  ₹399
# 4                    Women's Black Boyfriend T-shirt  ₹399
# 5                               Men's Jet Black Vest  ₹399
# 6  Women's Black Lost In The Mountains Boyfriend ...  ₹599
# 7  Men's Black Batman Outline Logo (BML) Printed ...  ₹499
# 8                 Men's White Marvel Printed T-shirt  ₹444
# 9                      Women's Red Boyfriend T-shirt  ₹399
#
#                                       Image_URL
# 0  https://images.bewakoof.com/web/Wishlist.svg
# 1  https://images.bewakoof.com/web/Wishlist.svg
# 2  https://images.bewakoof.com/web/Wishlist.svg
# 3  https://images.bewakoof.com/web/Wishlist.svg
# 4  https://images.bewakoof.com/web/Wishlist.svg
# 5  https://images.bewakoof.com/web/Wishlist.svg
# 6  https://images.bewakoof.com/web/Wishlist.svg
# 7  https://images.bewakoof.com/web/Wishlist.svg
# 8  https://images.bewakoof.com/web/Wishlist.svg
# 9  https://images.bewakoof.com/web/Wishlist.svg
# (10, 3)

# %% [markdown]
# ADDED NEW QUESTIONS:
# QUESTION-1

# %%
Page=requests.get("https://www.cnbc.com/world/?region=world")
soup=BeautifulSoup(Page.content)
headings=[]
date=[]
news_links=[]

for i in soup.find_all("a",class_="LatestNews-headline"):
    headings.append(i.text.replace("\n",""))
#print(len(headings))
for i in soup.find_all('time',class_="LatestNews-timestamp"):
    date.append(i.text.replace("\n","")) 
#print(len(date))
for i in soup.find_all('a',class_="LatestNews-headline"):
    b=i.get('href')
#print(len(b))    
    

df=pd.DataFrame({'headings':headings,'date':date,'news links':b})
print(df) 
print(df.shape)
# Out:
#                                              headings          date  \
# 0   OpenAI says in memo that Musk's claims ‘stem f...   7 Hours Ago
# 1   Waymo wins approval to expand robotaxi service...  10 Hours Ago
# 2   CEO explains why RadNet is piloting mammogram ...  11 Hours Ago
# 3   Cramer's Lightning Round: 'Not recommending' G...  11 Hours Ago
# 4   Cramer's week ahead: Watch for earnings from T...  11 Hours Ago
# 5   Super Micro joining S&P 500 after stock price ...  11 Hours Ago
# 6   Change Healthcare sets up a new electronic pre...  12 Hours Ago
# 7   Lockheed Martin looks to acquire spacecraft ma...  12 Hours Ago
# 8   Google Gemini head removes social media profil...  13 Hours Ago
# 9   Reddit seeking a valuation of up to $6.5 billi...  14 Hours Ago
# 10  NASA shuts down satellite refueling project af...  14 Hours Ago
# 11  Fed Chair Powell and jobs data take center sta...  14 Hours Ago
# 12  Here are the Nasdaq’s most beloved stocks that...  15 Hours Ago
# 13  What worked and didn't work this week from AI ...  15 Hours Ago
# 14  Judge rejects AstraZeneca’s challenge to Medic...  16 Hours Ago
# 15  What to know about this hot AI stock up nearly...  16 Hours Ago
# 16  Dell shares have best day since return to stoc...  16 Hours Ago
# 17  Appliances don't last like they used to, exper...  16 Hours Ago
# 18  Co-defendant in Sen. Bob Menendez corruption c...  16 Hours Ago
# 19  Stocks making the biggest moves midday: Spirit...  17 Hours Ago
# 20  These are the most overbought stocks with the ...  17 Hours Ago
# 21  AI startup Cohere says some rivals build Bugat...  17 Hours Ago
# 22  CVS and Walgreens to start selling abortion pi...  17 Hours Ago
# 23  7 places to retire abroad and live comfortably...  17 Hours Ago
# 24  Couple earns up to $70,000 a month, but still ...  18 Hours Ago
# 25  Wall Street is worried about NYCB's loan losse...  18 Hours Ago
# 26  This dividend strategy is swapping out chip st...  18 Hours Ago
# 27  The U.S. national debt is rising by $1 trillio...  18 Hours Ago
# 28  An analyst call on red-hot Broadcom indicates ...  18 Hours Ago
# 29  Trump lawyers urge judge to schedule classifie...  18 Hours Ago
#
#                                            news links
# 0   https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 1   https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 2   https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 3   https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 4   https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 5   https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 6   https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 7   https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 8   https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 9   https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 10  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 11  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 12  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 13  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 14  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 15  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 16  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 17  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 18  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 19  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 20  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 21  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 22  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 23  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 24  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 25  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 26  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 27  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 28  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# 29  https://www.cnbc.com/2024/03/01/trump-lawyers-...
# (30, 3)

# %% [markdown]
# QUESTION 2

# %%
Page=requests.get("https://www.keaipublishing.com/en/journals/artificial-intelligence-in-agriculture/most-downloaded-articles/")
soup=BeautifulSoup(Page.content)
Paper_title=[]
date=[]
author=[]

for i in soup.find_all("h2",class_="h5 article-title"):
    Paper_title.append(i.text.replace("\n"," ").replace('\r',''))
#print(len(Paper_title))
for i in soup.find_all('p',class_="article-date"):
    date.append(i.text.replace("\n","")) 
#print(len(date))
for i in soup.find_all('p',class_="article-authors"):
    author.append(i.text.replace("\n",""))
#print(len(author))    
    

df=pd.DataFrame({'Paper Title':Paper_title,'date':date,'Author':author})
print(df) 
print(df.shape)
# Out:
#                                           Paper Title            date  \
# 0                         Implementation of artifi...            2020
# 1                         Review of agricultural I...            2022
# 2                         A comprehensive review o...       June 2019
# 3                         Automation and digitizat...            2021
# 4                         Applications of electron...            2020
# 5                         Fruit ripeness classific...      March 2023
# 6                         A review of imaging tech...            2020
# 7                         Deep learning based comp...            2022
# 8                         Comparison of CNN-based ...  September 2023
# 9                         Transfer Learning for Mu...            2022
# 10                        Plant disease detection ...            2021
# 11                        Machine learning in nutr...  September 2023
# 12                        DeepRice: A deep learnin...      March 2024
# 13                        How artificial intellige...       June 2023
# 14                        Machine learning for wee...   December 2023
# 15                        Examining the interplay ...            2022
# 16                        Deep convolutional neura...            2022
# 17                        A systematic review of m...            2022
# 18                        A review on computer vis...            2020
# 19                        Crop diagnostic system: ...   December 2023
# 20                        Artificial cognition for...            2020
# 21                        Explainable artificial i...            2022
# 22                        Blockchain: A new safegu...            2020
# 23                        Study on body temperatur...      March 2019
# 24                        Vision Intelligence for ...      March 2024
#
#                                                Author
# 0    Tanha Talaviya |  Dhara Shah |  Nivedita Pate...
# 1          Jinyuan Xu |  Baoxing Gu |  Guangzhao Tian
# 2    Kirtan Jha |  Aalap Doshi |  Poojan Patel |  ...
# 3                            A. Subeesh |  C.R. Mehta
# 4                               Juzhong Tan |  Jie Xu
# 5    Matteo Rizzo |  Matteo Marcuzzo |  Alessandro...
# 6        Vijai Singh |  Namita Sharma |  Shikha Singh
# 7    V.G. Dhanya |  A. Subeesh |  N.L. Kushwaha | ...
# 8    Md Taimur Ahad |  Yan Li |  Bo Song |  Touhid...
# 9              Ananda S. Paymode |  Vandana B. Malode
# 10                         Punam Bedi |  Pushkar Gole
# 11   Oumnia Ennaji |  Leonardus Vergütz |  Achraf ...
# 12   P. Isaac Ritharson |  Kumudha Raimond |  X. A...
# 13            Vilani Sachithra |  L.D.C.S. Subhashini
# 14   Filbert H. Juwono |  W.K. Wong |  Seema Verma...
# 15   Abderahman Rejeb |  Karim Rejeb |  Suhaiza Za...
# 16   A. Subeesh |  S. Bhole |  K. Singh |  N.S. Ch...
# 17   Md Ekramul Hossain |  Muhammad Ashad Kabir | ...
# 18   Cedric Okinda |  Innocent Nyalala |  Tchalla ...
# 19               R. Abbasi |  P. Martinez |  R. Ahmad
# 20   Misbah Pathan |  Nivedita Patel |  Hiteshri Y...
# 21                                       Masahiro Ryo
# 22    Jie Xu |  Shuang Guo |  David Xie |  Yaxuan Yan
# 23          Zaiqin Zhang |  Hang Zhang |  Tonghai Liu
# 24   Galib Muhammad Shahriar Himel |  Md. Masudul ...
# (25, 3)
